# %% [markdown]
# # San Fernando Tracker (Colab)
# Ejecuta todo para correr el pipeline semanal.

# %%
# !pip install -q -r requirements.txt

# %%
from google.colab import files
uploaded = files.upload()
# Sube service_account.json

# %%
from main import run_pipeline
run_pipeline()
